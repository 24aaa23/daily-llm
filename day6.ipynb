# %%
import torch
import torch.nn as nn

# %%
import pandas as pd

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv("https://raw.githubusercontent.com/gscdit/Breast-Cancer-Detection/refs/heads/master/data.csv")
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
data=data.drop(columns=['id','Unnamed: 32'])

# %%
data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(data.iloc[:,1:],data.iloc[:,:1],test_size=0.2)

# %%
xtrain.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 28        15.300         25.27          102.40      732.4          0.10820
# 518       12.880         18.22           84.45      493.1          0.12180
# 287       12.890         13.12           81.89      515.9          0.06955
# 50        11.760         21.60           74.72      427.9          0.08637
# 424        9.742         19.12           61.93      289.7          0.10750
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 28            0.16970        0.168300              0.08751         0.1926
# 518           0.16610        0.048250              0.05303         0.1709
# 287           0.03729        0.022600              0.01171         0.1337
# 50            0.04966        0.016570              0.01115         0.1495
# 424           0.08333        0.008934              0.01967         0.2538
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 28                  0.06540  ...         20.27          36.71
# 518                 0.07253  ...         15.05          24.37
# 287                 0.05581  ...         13.62          15.54
# 50                  0.05888  ...         12.98          25.72
# 424                 0.07029  ...         11.21          23.17
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 28            149.30      1269.0           0.16410            0.61100
# 518            99.31       674.7           0.14560            0.29610
# 287            87.40       577.0           0.09616            0.11470
# 50             82.98       516.5           0.10850            0.08615
# 424            71.79       380.9           0.13980            0.13520
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 28           0.63350               0.20240          0.4027
# 518          0.12460               0.10960          0.2582
# 287          0.11860               0.05366          0.2309
# 50           0.05523               0.03715          0.2433
# 424          0.02085               0.04589          0.3196
#
#      fractal_dimension_worst
# 28                   0.09876
# 518                  0.08893
# 287                  0.06915
# 50                   0.06563
# 424                  0.08009
#
# [5 rows x 30 columns]

# %%
scalar=StandardScaler()
encoder=LabelEncoder()
xtrain=scalar.fit_transform(xtrain)
xtest=scalar.transform(xtest)
ytrain=encoder.fit_transform(ytrain)
ytest=encoder.transform(ytest)

# %%
xtrain
# Out:
# array([[ 0.31499416,  1.38821005,  0.41313284, ...,  1.32800674,
#          1.75317204,  0.84246957],
#        [-0.36179599, -0.25813377, -0.31642139, ..., -0.07341223,
#         -0.50327343,  0.30057546],
#        [-0.35899934, -1.44910586, -0.42046926, ..., -0.91819   ,
#         -0.92957765, -0.78982794],
#        ...,
#        [ 1.40289235, -0.79056835,  1.38451707, ...,  0.95499974,
#         -0.7203294 , -1.15586829],
#        [ 1.68535435,  1.75250744,  1.68528032, ...,  1.52130592,
#          0.57263726, -0.39457047],
#        [-0.59112161, -1.53784501, -0.62571985, ..., -0.66765612,
#         -0.60945904, -0.24793383]], shape=(455, 30))

# %%
xtrain1=torch.from_numpy(xtrain.astype(np.float32))
xtest1=torch.from_numpy(xtest.astype(np.float32))
ytrain1=torch.from_numpy(ytrain.astype(np.float32))
ytest1=torch.from_numpy(ytest.astype(np.float32))

# %%
class model(nn.Module):
    def __init__(self,vocab_size,embedded_size,hidden_dimension):
        super().__init__()
        self.embedding=nn.Embedding(vocab_size,embedded_size)
        self.rnn=nn.RNN(embedded_size,hidden_dimension,batch_first=True)
        self.linear1=nn.Linear(hidden_dimensions,16)
        self.relu==nn.Relu()
        self.linear2==nn.Linear(16,1)
        self.sigmid=nn.Sigmoid()
    def forwar(Self,features):
        out=self.linear1(features)
        out=self.relu(out)
        out=self.linear2(out)
        out=self.sigmoid(out)
        return out
