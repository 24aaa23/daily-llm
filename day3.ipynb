# %%
import torch

# %%
import torch.nn as nn

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
data=pd.read_csv("https://raw.githubusercontent.com/gscdit/Breast-Cancer-Detection/refs/heads/master/data.csv")

# %%
data.head()
data=data.drop(columns=['id','Unnamed: 32'])

# %%
xtrain ,xtest,ytrain,ytest= train_test_split(data.iloc[:,1:],data.iloc[:,:1] ,train_size=0.2)

# %%
xtrain.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 28         15.30         25.27          102.40      732.4          0.10820
# 190        14.22         23.12           94.37      609.9          0.10750
# 370        16.35         23.29          109.00      840.4          0.09742
# 65         14.78         23.94           97.40      668.3          0.11720
# 153        11.15         13.08           70.87      381.9          0.09754
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 28            0.16970         0.16830              0.08751         0.1926
# 190           0.24130         0.19810              0.06618         0.2384
# 370           0.14970         0.18110              0.08773         0.2175
# 65            0.14790         0.12670              0.09029         0.1953
# 153           0.05113         0.01982              0.01786         0.1830
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# ...

# %%
scaler=StandardScaler()
encoder=LabelEncoder()
xtrain =scaler.fit_transform(xtrain)
xtest=scaler.transform(xtest)
ytrain=encoder.fit_transform(ytrain)
ytest=encoder.fit_transform(ytest)
